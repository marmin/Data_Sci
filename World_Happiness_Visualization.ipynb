# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('/Users/Maryam/Desktop/Thinkful/projects/world-happiness-report/2017.csv')
new_df = df.iloc[:50,:]
plt.figure(figsize=(10, 10))
#plt.bar(new_df.Country, new_df.Freedom)
#plt.show()
#print(new_df.Freedom.sort_index())
#new_df.Freedom.sort_index().plot()
#plt.show()
TT = new_df.set_index(new_df.Country)
TT
TT.Freedom.plot(kind='bar')

# %%
plt.hist(df.loc[:,'Happiness.Score'], bins = 20)
plt.title('Histogram of countries with different Happiness Score')
plt.xlabel('Happiness Score')
plt.show()

# %%
plt.boxplot(df.loc[:,'Happiness.Score'])
plt.title('Box plot of Happiness score')
plt.show()

# %%
plt.plot(df.loc[:,'Generosity'])
plt.title('Generosity vs Country rank')
plt.xlabel('Country rank')
plt.ylabel('Generosity')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(df.loc[:,'Freedom'], color = 'purple')
plt.ylabel('Freedom')
plt.xlabel('Country Rank')

plt.subplot(1,2,2)
plt.plot(df.loc[:,'Health..Life.Expectancy.'], color = 'green')
plt.ylabel('Life Expentancy')
plt.xlabel('Country Rank')
plt.show()
